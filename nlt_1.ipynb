# %%
name = "NPL LAb"
hours=30
pi=3.14
topics = ["tokenization","pos tagging","NER"]

# %%
if hours > 25:
    print("sufficient hours for learing python.")
else:
    print("add more practice hours.")
# Out:
# sufficient hours for learing python.

# %%
for topic in topics:
    print("learing:",topic)
# Out:
# learing: tokenization
# learing: pos tagging
# learing: NER

# %%
#function
def greet(student_name):
        return "welcome to " + student_name

# %%
print(greet("AI & NLP Lab"))
# Out:
# welcome to AI & NLP Lab
